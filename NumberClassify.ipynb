# %% [markdown]
# # Image - Number Classification

# %% [markdown]
# ## Importing libs and Preprocessing

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# from tensorflow.keras.utils import to_categorical
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Flatten, Dense, Dropout

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
plt.imshow(x_train[0])
plt.colorbar()

# %% [markdown]
# Divide to 255 to rescale from [0 , 255] to [0 , 1]

# %%
x_train, x_test = x_train[..., np.newaxis]/255.0, x_test[..., np.newaxis]/255.0
# Out:
# Number of original training examples: 60000
# Number of original test examples: 10000

# %%
plt.figure(figsize=(12,15))
for i,x in enumerate(x_train,1):
    if i<=12:
        plt.subplot(3,4,i)
        plt.imshow(x_train[i-1])
        plt.colorbar()
        plt.xlabel(y_train[i-1])

# %% [markdown]
# This is Multi-class Classification problems so we are going to one hot encoding of label:

# %%
y_train=tf.keras.utils.to_categorical(y_train)
y_test=tf.keras.utils.to_categorical(y_test)

# %% [markdown]
# ## Modeling

# %% [markdown]
# We are going to use CNN in this classification project <br> <br>
# One thing to be noticed here that CNN is useful for finding patterns in images to recognize objects, classes, and categories
